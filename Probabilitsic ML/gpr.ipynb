# %%
# !pip install plotly
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/16.1 MB ? eta -:--:--
#     --------------------------------------- 0.3/16.1 MB ? eta -:--:--
#    - -------------------------------------- 0.8/16.1 MB 3.0 MB/s eta 0:00:06
#    --- ------------------------------------ 1.3/16.1 MB 3.0 MB/s eta 0:00:05
#    ----- ---------------------------------- 2.1/16.1 MB 2.8 MB/s eta 0:00:06
#    ------ --------------------------------- 2.6/16.1 MB 2.8 MB/s eta 0:00:05
#    ------- -------------------------------- 2.9/16.1 MB 2.7 MB/s eta 0:00:05
#    -------- ------------------------------- 3.4/16.1 MB 2.6 MB/s eta 0:00:05
#    --------- ------------------------------ 3.9/16.1 MB 2.6 MB/s eta 0:00:05
#    ----------- ---------------------------- 4.5/16.1 MB 2.5 MB/s eta 0:00:05
#    ----------- ---------------------------- 4.7/16.1 MB 2.5 MB/s eta 0:00:05
# ...

# %%
import numpy as np
import plotly.graph_objects as go
from ipywidgets import interact, widgets
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 import numpy as np
# ----> 2 import plotly.graph_objects as go
#       3 from ipywidgets import interact, widgets
#
# ModuleNotFoundError: No module named 'plotly'
